# %%
import numpy as np
import pandas as pd
from sklearn import *
from sklearn.model_selection import *

# %%
feature_data = pd.read_excel('Datasets/LSVT_voice_rehabilitation/LSVT_voice_rehabilitation.xlsx', 0)
label_data = pd.read_excel('Datasets/LSVT_voice_rehabilitation/LSVT_voice_rehabilitation.xlsx', 1)

# %%
label_data.loc[label_data["Binary class 1=acceptable, 2=unacceptable"] == 1] = 0
label_data.loc[label_data["Binary class 1=acceptable, 2=unacceptable"] == 2] = 1

# %%
Net_data = pd.concat([feature_data,label_data], axis = 1)
display(Net_data)
# Out:
#      Jitter->F0_abs_dif  Jitter->F0_dif_percent  \
# 0              0.088112                0.041697
# 1              0.161798                0.057364
# 2              0.554508                0.642913
# 3              0.031089                0.027108
# 4              0.076177                0.039071
# ..                  ...                     ...
# 121            0.116214                0.070546
# 122            0.700258                0.334397
# 123            0.072635                0.050743
# 124            0.111362                0.054237
# 125            0.256953                0.132694
#
#      Jitter->F0_PQ5_classical_Schoentgen  Jitter->F0_PQ5_classical_Baken  \
# 0                               0.000480                   -3.723304e-06
# 1                               0.000677                    5.466365e-06
# 2                               0.007576                   -7.443871e-07
# 3                               0.000314                   -2.214722e-07
# 4                               0.000302                    2.732106e-05
# ..                                   ...                             ...
# 121                             0.000837                    2.765074e-06
# 122                             0.003959                    8.297261e-06
# 123                             0.000597                   -5.277518e-06
# 124                             0.000646                   -1.546671e-06
# 125                             0.001576                    2.252403e-06
#
#      Jitter->F0_PQ5_generalised_Schoentgen  Jitter->F0_abs0th_perturb  \
# 0                                 0.000422                   2.458381
# 1                                 0.000206                   2.592066
# 2                                 0.006488                  12.691326
# 3                                 0.000216                   0.754288
# 4                                 0.001102                   1.270034
# ..                                     ...                        ...
# 121                               0.000333                   1.890006
# 122                               0.001516                   4.557797
# 123                               0.000434                   6.984651
# 124                               0.000277                   1.935398
# 125                               0.000708                   2.339807
#
#      Jitter->F0_CV  Jitter->F0_TKEO_mean  Jitter->F0_TKEO_std  \
# 0     6.332164e-07             47.021079          1366.430390
# 1     7.228518e-07             93.557936          2582.922776
# 2     6.946246e-04             52.988422           466.682635
# 3     1.868647e-07             13.982754           417.217249
# 4     4.918186e-05             56.373996          1608.317410
# ..             ...                   ...                  ...
# 121   9.844257e-07             34.083311           896.672947
# 122   1.581899e-05            104.648435          1583.166169
# 123   4.993260e-07             21.859427           625.288493
# 124   4.398078e-07             47.870508          1367.843467
# 125   3.050831e-06             52.103851          1124.445571
#
#      Jitter->F0_TKEO_prc5  ...  det_TKEO_std4_2_coef  det_TKEO_std4_3_coef  \
# 0               -7.103323  ...              7.088978             19.753255
# 1              -23.284761  ...              7.977363             22.203504
# 2              -45.308680  ...              5.078616             14.135923
# 3               -1.207741  ...              5.610448             15.626164
# 4               -3.491990  ...              6.902199             19.117609
# ..                    ...  ...                   ...                   ...
# 121            -10.446397  ...              6.527285             18.210931
# 122            -97.281717  ...              7.160142             20.081389
# 123             -4.116001  ...              6.141876             17.095325
# 124             -9.373059  ...              7.125849             19.849347
# 125            -38.918940  ...              6.853709             19.071984
#
#      det_TKEO_std4_4_coef  det_TKEO_std4_5_coef  det_TKEO_std4_6_coef  \
# 0               54.335046            145.528630            375.097397
# 1               60.993338            163.560972            421.010306
# 2               38.641654            103.466808            264.654626
# 3               42.943275            115.014975            296.320795
# 4               52.715873            141.113865            363.511021
# ..                    ...                   ...                   ...
# 121             50.085484            134.123291            345.396264
# 122             55.178858            147.584708            379.897760
# 123             46.893015            125.687344            323.728298
# 124             54.508453            146.094711            376.377835
# 125             52.318080            140.093685            360.725864
#
#      det_TKEO_std4_7_coef  det_TKEO_std4_8_coef  det_TKEO_std4_9_coef  \
# 0              921.296579           2137.079844           4697.131077
# 1             1036.092589           2404.072562           5284.082128
# 2              649.657090           1507.384591           3315.804236
# 3              728.284936           1689.586636           3713.818933
# 4              893.246151           2071.625622           4554.204815
# ..                    ...                   ...                   ...
# 121            850.942761           1973.383824           4336.099395
# 122            935.982559           2166.960428           4769.956102
# 123            795.715774           1845.609006           4056.256338
# 124            926.435019           2147.499571           4717.270683
# 125            885.933217           2052.423390           4511.560376
#
#      det_TKEO_std4_10_coef  Binary class 1=acceptable, 2=unacceptable
# 0              9931.208257                                          0
# 1             11165.095662                                          1
# 2              6974.600636                                          1
# 3              7851.139360                                          0
# 4              9623.566242                                          1
# ..                     ...                                        ...
# 121            9158.984652                                          1
# 122           10067.750435                                          1
# 123            8583.121863                                          0
# 124            9966.759379                                          1
# 125            9542.064446                                          1
#
# [126 rows x 311 columns]

# %%
d_train, d_test = train_test_split(Net_data, test_size =0.5, shuffle=True)
print(len(d_train))
print(type(d_train))
# Out:
# 63
# <class 'pandas.core.frame.DataFrame'>

# %%
X_train = d_train.iloc[:, :-1]
X_test = d_test.iloc[:, :-1] #this is a numpy array
print(type(X_train))
print(type(X_test))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
y_train = d_train.iloc[:,-1:]
y_test = d_test.iloc[:,-1:]

# %%
print(y_train)
print(y_test)
# Out:
#      Binary class 1=acceptable, 2=unacceptable
# 58                                           1
# 36                                           0
# 107                                          1
# 113                                          1
# 83                                           1
# ..                                         ...
# 102                                          0
# 85                                           1
# 109                                          1
# 7                                            1
# 45                                           0
#
# [63 rows x 1 columns]
#      Binary class 1=acceptable, 2=unacceptable
# 11                                           1
# 50                                           1
# 114                                          0
# 80                                           1
# 123                                          0
# ..                                         ...
# 76                                           1
# 75                                           0
# 16                                           1
# 37                                           1
# 78                                           0
#
# [63 rows x 1 columns]

# %%
y_train = y_train.to_numpy()
y_test = y_test.to_numpy()

# %%
X_train = X_train.to_numpy() #rerunning might cause issue because of changed type in cached memory
X_test = X_test.to_numpy()

# %%
model = linear_model.Perceptron()
model.fit(X_train, y_train.ravel()) #needs 1D array shape
# Out:
# Perceptron()
